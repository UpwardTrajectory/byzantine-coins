# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

gauth = GoogleAuth()
gauth.LocalWebserverAuth()

drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=672805379389-vv20fv8vtjb7rjhlsn6gqokc70u1c4k3.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
folders = {
    "A2": "15-qoa2w60FecoSnwzbPRudpuIxHirCh1", 
    "E": "1V_zjKxuhk-qcxFS40jRGwtt93dBQCieR", 
    "F": "1kl0NhQCrp7nZ3Mum3B9lO_6LgkxKkA_H",
    "G": "1k23Suv4XszB-TshfGu_7l4WzTK4gOe1L", 
}

# %%
file_list = drive.ListFile().GetList()

# %%
test_file = file_list[0]

for k, v in test_file.items():
    print(k, ": ", v)
# Out:
# kind :  drive#file
# id :  1ixAhgItdLtTl-00RhmrO7QGtIIPOE445
# etag :  "f2P4MDc1XjqPgJingShxcnjxANQ/MTU4MzY0ODc5MjQzOQ"
# selfLink :  https://www.googleapis.com/drive/v2/files/1ixAhgItdLtTl-00RhmrO7QGtIIPOE445
# webContentLink :  https://drive.google.com/uc?id=1ixAhgItdLtTl-00RhmrO7QGtIIPOE445&export=download
# alternateLink :  https://drive.google.com/file/d/1ixAhgItdLtTl-00RhmrO7QGtIIPOE445/view?usp=drivesdk
# embedLink :  https://drive.google.com/file/d/1ixAhgItdLtTl-00RhmrO7QGtIIPOE445/preview?usp=drivesdk
# iconLink :  https://drive-thirdparty.googleusercontent.com/16/type/image/jpeg
# thumbnailLink :  https://lh3.googleusercontent.com/UDwEcCubx6xgzxEnwE_Zh_dms-MYY229ZbeIJHOvvGacujvNH0okVB3lRDlp4XbM-5XFUEOSWlo=s220
# title :  Lanz 171 - Var 31 - 16.9gm 33mm - O1.jpg
# mimeType :  image/jpeg
# labels :  {'starred': False, 'hidden': False, 'trashed': False, 'restricted': False, 'viewed': True}
# copyRequiresWriterPermission :  False
# createdDate :  2020-03-08T06:26:32.439Z
# ...

# %%
fname = test_file['originalFilename']
test_file.GetContentFile(fname)

# %%
def dl_file(file_obj, folder='A2'):
    fname = file_obj['originalFilename']
    fpath = f".raw_images/{folder}/"
    file_obj.GetContentFile(fpath)

dl_file(test_file, "test")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-56-08b38e812fd3> in <module>
#       4     file_obj.GetContentFile(fpath)
#       5
# ----> 6 dl_file(test_file, "test")
#
# <ipython-input-56-08b38e812fd3> in dl_file(file_obj, folder)
#       2     fname = file_obj['originalFilename']
#       3     fpath = f".raw_images/{folder}/"
# ----> 4     file_obj.GetContentFile(fpath)
#       5
#       6 dl_file(test_file, "test")
#
# C:\ProgramData\Miniconda3\lib\site-packages\pydrive\files.py in GetContentFile(self, filename, mimetype, remove_bom)
#     209                     self.has_bom == remove_bom:
#     210       self.FetchContent(mimetype, remove_bom)
# --> 211     f = open(filename, 'wb')
#     212     f.write(self.content.getvalue())
#     213     f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '.raw_images/test/'

# %%
drive.ListFile({'q': f"'{folders['E']}' in parents"}).GetList()
# Out:
# [GoogleDriveFile({'kind': 'drive#file', 'id': '1yf7C-hq_YyiYvJsAPZ-kkJSNC4GEjUTI', 'etag': '"f2P4MDc1XjqPgJingShxcnjxANQ/MTU4MzUzNTM1NTg1OA"', 'selfLink': 'https://www.googleapis.com/drive/v2/files/1yf7C-hq_YyiYvJsAPZ-kkJSNC4GEjUTI', 'webContentLink': 'https://drive.google.com/uc?id=1yf7C-hq_YyiYvJsAPZ-kkJSNC4GEjUTI&export=download', 'alternateLink': 'https://drive.google.com/file/d/1yf7C-hq_YyiYvJsAPZ-kkJSNC4GEjUTI/view?usp=drivesdk', 'embedLink': 'https://drive.google.com/file/d/1yf7C-hq_YyiYvJsAPZ-kkJSNC4GEjUTI/preview?usp=drivesdk', 'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/image/jpeg', 'thumbnailLink': 'https://lh3.googleusercontent.com/EDjJivnUgKZHZByHCL-DGeF2eU-VUxAruU1l5cft4f6I6OzQJgtanqFQzaO2HTvUDa4Wlu5Eey8=s220', 'title': 'acsearch E-15.jpg', 'mimeType': 'image/jpeg', 'description': '[#Beginning of Shooting Data Section]\rImage Size:S (2784 x 1856), DX\r02.12.2018 05:59:19.20\rTime Zone and Date:UTC+8, DST:OFF\rJpeg Fine (8-bit)\rNikon D7500\rLens:
# ...

# %%
folders[E]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-697d69422074> in <module>
# ----> 1 folders[E]
#
# NameError: name 'E' is not defined
